# %% [markdown]
# # Fase 5 — LGD e EAD
#
# Objetivo: estimar Loss Given Default por segmento com premissas documentadas (BCB WPS193) e definir a Exposure at Default (saldo x fator de utilizacao), justificando a formula.

# %%
import numpy as np
import pandas as pd

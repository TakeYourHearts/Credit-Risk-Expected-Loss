# %% [markdown]
# # Fase 6 — Perda Esperada (Expected Loss)
#
# Objetivo: consolidar EL = PD x LGD x EAD por cliente, analisar a distribuicao da perda esperada, o EL total do portfolio e a sensibilidade ao modelo de PD utilizado.

# %%
import numpy as np
import pandas as pd

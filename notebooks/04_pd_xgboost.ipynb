# %% [markdown]
# # Fase 4 — PD: XGBoost (benchmark)
#
# Objetivo: treinar um benchmark nao-linear com as mesmas variaveis, interpretar via SHAP e comparar diretamente com a logistica em termos de poder discriminante e explicabilidade.

# %%
import numpy as np
import pandas as pd
